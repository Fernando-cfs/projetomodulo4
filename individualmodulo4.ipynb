# %% [markdown]
# <a href="https://colab.research.google.com/github/Fernando-cfs/projetomodulo4/blob/main/individualmodulo4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #<font color = red> Projeto Individual Modulo 4

# %% [markdown]
# ## Sobre o Negócio
#
# A empresa 'Soft' de desenvolvimento de software quer expandir no mercado global para isso, quer saber como anda o desempenho dos seus funcionários e como pode melhorar para ter maior proveito deles e com isso maior satisfação dos clientes para eles se torna uma referência em sua área para isso será gerado insights em relação aos seguintes tópicos: Dia,	Horas Trabalhadas,	Bugs Corrigidos,	Tarefas Concluídas. Com essas informações teremos insights de como anda o desempenhos dos funcionários da 'Soft' e como melhora-los

# %% [markdown]
# ## Importando as bibliotecas
# - Pandas
# - plotly.express
# - plotly.graph_objects

# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# ## Criação das tabelas
# - Dia
# - Horas Trabalhadas
# - Bugs Corrigidos
# - Tarefas concluídas

# %%
tabelas = {'Dia': ['Segunda','Terça', 'Quarta','Quinta','Sexta','Sábado', 'Domingo'],
         'Horas Trabalhadas': [6,7,8,6,7,5,4],
              'Bugs Corrigidos': [3,2,1,4,3,2,1],
              'Tarefas Concluídas': [5,4,6,4,5,3,2]}

dftabelas = pd.DataFrame(tabelas)
dftabelas
# Out:
#        Dia  Horas Trabalhadas  Bugs Corrigidos  Tarefas Concluídas
# 0  Segunda                  6                3                   5
# 1    Terça                  7                2                   4
# 2   Quarta                  8                1                   6
# 3   Quinta                  6                4                   4
# 4    Sexta                  7                3                   5
# 5   Sábado                  5                2                   3
# 6  Domingo                  4                1                   2

# %%
# Estatistica descritivas sobre a tabela
dftabelas.describe()
# Out:
#        Horas Trabalhadas  Bugs Corrigidos  Tarefas Concluídas
# count           7.000000         7.000000            7.000000
# mean            6.142857         2.285714            4.142857
# std             1.345185         1.112697            1.345185
# min             4.000000         1.000000            2.000000
# 25%             5.500000         1.500000            3.500000
# 50%             6.000000         2.000000            4.000000
# 75%             7.000000         3.000000            5.000000
# max             8.000000         4.000000            6.000000

# %% [markdown]
# Na análise descritiva do desempenho dos funcionários de uma empresa podemos observar que 75% das horas trabalhadas esta a baixo de 7 horas e que a minima de horas trabalhadas e de 4 horas e a máxima e de 8 horas

# %%
# correlacao
dftabelas.corr(numeric_only=True)
# Out:
#                     Horas Trabalhadas  Bugs Corrigidos  Tarefas Concluídas
# Horas Trabalhadas            1.000000         0.079536            0.907895
# Bugs Corrigidos              0.079536         1.000000            0.190885
# Tarefas Concluídas           0.907895         0.190885            1.000000

# %% [markdown]
# Na correlação entre bug e horas trabalhas não é muito grande, tem uma correlação maior entre horas trabalhas e tarefas concluídas

# %% [markdown]
# ## Criação dos cálculos média diaria, total e gráficos
#
#
# - Total de Horas Trabalhadas
# - Média Diária de Horas Trabalhadas

# %%
# Criar DataFrame a partir das tabelas
horas = pd.DataFrame(tabelas)

# Calcular a média e a soma total das horas trabalhadas
media_horas = horas['Horas Trabalhadas'].mean()
total_horas = horas['Horas Trabalhadas'].sum()

# Criar figura com os dados
fig = go.Figure()

# Adicionar as barras para média e total e configuralas
fig.add_trace(go.Bar(x=['Média Diária', 'Total por Semana'],
                     y=[media_horas, total_horas],
                     marker=dict(color=['green', 'red']),
                     text=[f'Média: {media_horas:.2f} horas', f'Total: {total_horas:.2f} horas'],
                     textposition='auto'
                    ))
# Personalizar o layout do gráfico
fig.update_layout(title='Média e Total de Horas Trabalhadas por Semana',
                  title_x=0.5,  # Alinhar o título no centro do gráfico
                  xaxis_title='Estatísticas',
                  yaxis_title='Horas',
                  showlegend=False,
                  width=600  # Definindo a largura do gráfico para 600 pixels
                  )
# Mostrar o gráfico interativo
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="6dc11b60-2c1d-4f50-85ea-97c3d82f592f" class="plotly-graph-div" style="height:525px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6dc11b60-2c1d-4f50-85ea-97c3d82f592f")) {                    Plotly.newPlot(                        "6dc11b60-2c1d-4f50-85ea-97c3d82f592f",                        [{"marker":{"color":["green","red"]},"text":["M\u00e9dia: 6.14 horas","Total: 43.00 horas"],"textposition":"auto","x":["M\u00e9dia Di\u00e1ria","Total por Semana"],"y":[6.142857142857143,43],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"t ...

# %% [markdown]
# -------------------------------------------------------------------------------
#
# - Total de Bugs Corrigidos
# - Média Diária de Bugs Corrigidos

# %%
# Criar DataFrame a partir das tabelas
bgcorrigidos = pd.DataFrame(tabelas)

# Calcular a média e a soma total dos Bugs Corrigidos
media_bgcorrigidos = horas['Bugs Corrigidos'].mean()
total_bgcorrigidos = horas['Bugs Corrigidos'].sum()

# Criar figura com os dados
fig = go.Figure()

# Adicionar as barras para média e total e configuralas
fig.add_trace(go.Bar(x=['Média Diária', 'Total por Semana'],
                     y=[media_bgcorrigidos, total_bgcorrigidos],
                     marker=dict(color=['green', 'red']),
                     text=[f'Média: {media_bgcorrigidos:.2f} bgcorrigidos', f'Total: {total_bgcorrigidos:.2f} bgcorrigidos'],
                     textposition='auto'
                    ))
# Personalizar o layout do gráfico
fig.update_layout(title='Média e Total de Bugs Corrigidos por Semana',
                  title_x=0.5,  # Alinhar o título no centro do gráfico
                  xaxis_title='Estatísticas',
                  yaxis_title='Bugs Corrigidos',
                  showlegend=False,
                  width=600  # Definindo a largura do gráfico para 600 pixels
                  )
# Mostrar o gráfico interativo
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="afe9d7e9-d4a7-471d-89a5-2e0d029c116c" class="plotly-graph-div" style="height:525px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("afe9d7e9-d4a7-471d-89a5-2e0d029c116c")) {                    Plotly.newPlot(                        "afe9d7e9-d4a7-471d-89a5-2e0d029c116c",                        [{"marker":{"color":["green","red"]},"text":["M\u00e9dia: 2.29 bgcorrigidos","Total: 16.00 bgcorrigidos"],"textposition":"auto","x":["M\u00e9dia Di\u00e1ria","Total por Semana"],"y":[2.2857142857142856,16],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"sol ...

# %% [markdown]
# --------------------------------------------------------------------------------
#
# - Total de Tarefas Concluídas
# - Média Diária de Tarefas Concluídas

# %%
# Criar DataFrame a partir das tabelas
tconcluidas = pd.DataFrame(tabelas)

# Calcular a média e a soma total dos Tarefas Concluídas
media_tconcluidas = horas['Tarefas Concluídas'].mean()
total_tconcluidas = horas['Tarefas Concluídas'].sum()

# Criar figura com os dados
fig = go.Figure()

# Adicionar as barras para média e total e configuralas
fig.add_trace(go.Bar(x=['Média Diária', 'Total por Semana'],
                     y=[media_tconcluidas, total_tconcluidas],
                     marker=dict(color=['green', 'red']),
                     text=[f'Média: {media_tconcluidas:.2f} tconcluidas', f'Total: {total_tconcluidas:.2f} tconcluidas'],
                     textposition='auto'
                    ))
# Personalizar o layout do gráfico
fig.update_layout(title='Média e Total de Tarefas Concluídas por Semana',
                  title_x=0.5,  # Alinhar o título no centro do gráfico
                  xaxis_title='Estatísticas',
                  yaxis_title='Tarefas Concluídas',
                  showlegend=False,
                  width=600  # Definindo a largura do gráfico para 600 pixels
                  )
# Mostrar o gráfico interativo
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="599c47e1-41c1-4aae-9a5c-4e273b3d076b" class="plotly-graph-div" style="height:525px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("599c47e1-41c1-4aae-9a5c-4e273b3d076b")) {                    Plotly.newPlot(                        "599c47e1-41c1-4aae-9a5c-4e273b3d076b",                        [{"marker":{"color":["green","red"]},"text":["M\u00e9dia: 4.14 tconcluidas","Total: 29.00 tconcluidas"],"textposition":"auto","x":["M\u00e9dia Di\u00e1ria","Total por Semana"],"y":[4.142857142857143,29],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidi ...

# %% [markdown]
# --------------------------------------------------------------------------------
#
# - Produtividade Diária (Tarefas Concluídas por Hora)

# %%
# Criar DataFrame a partir das tabelas
dftabelas = pd.DataFrame(tabelas)

# Calcular a produtividade diária (tarefas concluídas por hora) para cada dia da semana
dftabelas['Produtividade Diária'] = (dftabelas['Tarefas Concluídas'] / dftabelas['Horas Trabalhadas']).round(2)

# Definir o dia da semana em português
days_of_week = {
    'Segunda': 'Segunda-feira',
    'Terça': 'Terça-feira',
    'Quarta': 'Quarta-feira',
    'Quinta': 'Quinta-feira',
    'Sexta': 'Sexta-feira',
    'Sábado': 'Sábado',
    'Domingo': 'Domingo'
}
dftabelas['Dia da Semana'] = dftabelas['Dia'].map(days_of_week)

# Criar o gráfico de barras com o Plotly
fig = px.bar(dftabelas, x='Dia da Semana', y='Produtividade Diária', text='Produtividade Diária',
             hover_data={'Horas Trabalhadas': True, 'Tarefas Concluídas': True},
             labels={'Produtividade Diária': 'Produtividade Diária (Tarefas Concluídas por Hora)'},
             color_discrete_sequence=px.colors.qualitative.Set2)

# Personalizar o layout do gráfico
fig.update_layout(title='Produtividade Diária ao Longo da Semana',
                  title_x=0.5,  # Alinhar o título no centro do gráfico
                  xaxis_title='Dia da Semana',
                  yaxis_title='Produtividade Diária (Tarefas Concluídas por Hora)',
                  xaxis={'categoryorder': 'array', 'categoryarray': list(days_of_week.values())},
                  xaxis_tickangle=-45,
                  barmode='group',
                  bargap=0.2,
                  bargroupgap=0.1)

# Mostrar o gráfico interativo
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="b914b398-6a4a-4c97-9351-8e51bc934199" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b914b398-6a4a-4c97-9351-8e51bc934199")) {                    Plotly.newPlot(                        "b914b398-6a4a-4c97-9351-8e51bc934199",                        [{"alignmentgroup":"True","customdata":[[6,5],[7,4],[8,6],[6,4],[7,5],[5,3],[4,2]],"hovertemplate":"Dia da Semana=%{x}<br>Produtividade Di\u00e1ria (Tarefas Conclu\u00eddas por Hora)=%{text}<br>Horas Trabalhadas=%{customdata[0]}<br>Tarefas Conclu\u00eddas=%{customdata[1]}<extra></extra>","legendgroup":"","marker":{"color":"rgb(102,194,165)","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[0.83,0.57,0.75,0.67,0.71,0.6,0.5],"textposition":"auto","x":["Segunda-feira","Ter\u00e7a-feira","Quarta-feira","Quinta-feira","Sexta-feira","S\u00e1bado","Domingo"],"xaxis":"x","y":[0.83,0.57,0.75,0.67,0.71,0.6,0.5],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth": ...

# %%
# Criar DataFrame a partir das tabelas
dftabelas = pd.DataFrame(tabelas)

# Calcular os Bugs Corrigidos por Hora para cada dia da semana
dftabelas['Bugs Corrigidos por Hora'] = (dftabelas['Bugs Corrigidos'] / dftabelas['Horas Trabalhadas']).round(2)

# Definir o dia da semana em português
days_of_week = {
    'Segunda': 'Segunda-feira',
    'Terça': 'Terça-feira',
    'Quarta': 'Quarta-feira',
    'Quinta': 'Quinta-feira',
    'Sexta': 'Sexta-feira',
    'Sábado': 'Sábado',
    'Domingo': 'Domingo'
}
dftabelas['Dia da Semana'] = dftabelas['Dia'].map(days_of_week)

# Criar o gráfico de barras com o Plotly
fig = px.bar(dftabelas, x='Dia da Semana', y='Bugs Corrigidos por Hora', text='Bugs Corrigidos por Hora',
             hover_data={'Horas Trabalhadas': True, 'Bugs Corrigidos': True},
             labels={'Bugs Corrigidos por Hora': 'Bugs Corrigidos (Bugs Corrigidos por Hora)'},
             color_discrete_sequence=px.colors.qualitative.Set2)

# Personalizar o layout do gráfico
fig.update_layout(title='Bugs Corrigidos por Hora ao Longo da Semana',
                  title_x=0.5,  # Alinhar o título no centro do gráfico
                  xaxis_title='Dia da Semana',
                  yaxis_title='Bugs Corrigidos (Bugs Corrigidos por Hora)',
                  xaxis={'categoryorder': 'array', 'categoryarray': list(days_of_week.values())},
                  xaxis_tickangle=-45,
                  barmode='group',
                  bargap=0.2,
                  bargroupgap=0.1)

# Mostrar o gráfico interativo
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="3134ac7f-7125-4e25-b76d-a6b5b302d45b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3134ac7f-7125-4e25-b76d-a6b5b302d45b")) {                    Plotly.newPlot(                        "3134ac7f-7125-4e25-b76d-a6b5b302d45b",                        [{"alignmentgroup":"True","customdata":[[6,3],[7,2],[8,1],[6,4],[7,3],[5,2],[4,1]],"hovertemplate":"Dia da Semana=%{x}<br>Bugs Corrigidos (Bugs Corrigidos por Hora)=%{text}<br>Horas Trabalhadas=%{customdata[0]}<br>Bugs Corrigidos=%{customdata[1]}<extra></extra>","legendgroup":"","marker":{"color":"rgb(102,194,165)","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[0.5,0.29,0.12,0.67,0.43,0.4,0.25],"textposition":"auto","x":["Segunda-feira","Ter\u00e7a-feira","Quarta-feira","Quinta-feira","Sexta-feira","S\u00e1bado","Domingo"],"xaxis":"x","y":[0.5,0.29,0.12,0.67,0.43,0.4,0.25],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{" ...

# %% [markdown]
# ## Relatório
# - Tivemos uma média diária de 6.14 horas trabalhadas com uma média de 4.14 terefaz concluídas e a média de 2.29 bugs corrigidos
# - O total de horas trabalhadas por semana e de 43 horas, O total de tarefaz conclídas e de 29 tarefas, E o total de bugs corrigidos e de 16 bugs
# - Produtividade Diária (Tarefas Concluídas por Hora) na segunda-feira teve o maior desempenho de tarefaz comcluídas por horas e domingo o menor
# - Temos a quatidades de bugs corrigidos por hora e vimos que na quarta feira tivemos o menor números de bugs corrigidos em relação as horas e na quinta-feira o maior números de bugs corrigido em relação as horas
